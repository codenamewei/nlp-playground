# %%
from youtube2text import Youtube2Text

converter = Youtube2Text(outputpath = r"C:\Users\codenamewei\Downloads")

# %% [markdown]
# ### Select output folder during youtube url -> text

# %%
converter.url2text(urlpath = "https://www.youtube.com/watch?v=Ad9Q8rM0Am0&t=114s", outfilename = "simonsinek")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\CODENA~1\AppData\Local\Temp/ipykernel_20600/1336765876.py in <module>
# ----> 1 converter.url2text(urlpath = "https://www.youtube.com/watch?v=Ad9Q8rM0Am0&t=114s", outfilename = "simonsinek")
#
# ~\.conda\envs\nlp-playground\lib\site-packages\youtube2text-0.0.9a0-py3.8.egg\youtube2text\youtube2text.py in url2text(self, urlpath, outfilename, mode)
#      76
#      77         self.url2audio(urlpath, audiofilename = outfilename)
# ---> 78         self.audio2text(audiofilename = outfilename, textfilename = outfilename, mode = mode)
#      79
#      80     def url2audio(self, urlpath, audiofilename, audiofilepath = None):
#
# ~\.conda\envs\nlp-playground\lib\site-packages\youtube2text-0.0.9a0-py3.8.egg\youtube2text\youtube2text.py in audio2text(self, audiofilename, audiofilepath, textfilename, textfilepath, mode)
# ...

# %% [markdown]
# ### youtube to audio

# %% [markdown]
# ### audio to text
